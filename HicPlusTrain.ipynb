# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import gzip
from utility import *
import tensorflow as tf
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\yymjzq\Anaconda3\envs\tensorflow\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['colors', 'log']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
pylab.rcParams['figure.figsize'] = (40, 20)
sys.setrecursionlimit(10000)
conv2d1_filters_numbers = 8
conv2d1_filters_size = 9
conv2d2_filters_numbers = 8
conv2d2_filters_size = 1
conv2d3_filters_numbers = 1
conv2d3_filters_size = 5

down_sample_ratio = 16
learning_rate = 0.00001
epochs = 10
HiC_max_value = 100

# %%
# low_resolution_samples = np.load(gzip.GzipFile('../data/GM12878_replicate_down16_chr19_22.npy.gz', "r")) * down_sample_ratio
# high_resolution_samples = np.load(gzip.GzipFile('../data/GM12878_replicate_original_chr19_22.npy.gz', "r"))
# low_resolution_samples_val = np.load(gzip.GzipFile('../data/GM12878_replicate_down16_chr17_17.npy.gz', "r")) * down_sample_ratio
# N, d, w, h = low_resolution_samples.shape
# low_resolution_samples = low_resolution_samples[:, 0, :, :].reshape(N, w, h, d)
# high_resolution_samples = high_resolution_samples[:, 0, :, :].reshape(N, w, h, d)
low_resolution_samples, high_resolution_samples, cache = loadData(40, 40, 28, 28, root="../../")
low_resolution_samples = low_resolution_samples.reshape(-1, 40, 40, 1)
high_resolution_samples = high_resolution_samples.reshape(-1, 40, 40, 1)
# Out:
# Starting to load data...
# expected:  17 17
# actual: 17 17 289
# expected:  17 17
# actual: 17 17 289
# expected:  17 16
# actual: 17 16 272
# expected:  17 16
# actual: 17 16 272
# expected:  17 13
# actual: 17 13 221
# expected:  17 13
# actual: 17 13 221
# expected:  17 13
# actual: 17 13 221
# expected:  17 13
# actual: 17 13 221
# expected:  17 12
# actual: 17 12 204
# expected:  17 12
# actual: 17 12 204
# expected:  17 11
# actual: 17 11 187
# expected:  17 11
# actual: 17 11 187
# expected:  17 10
# actual: 17 10 170
# expected:  17 10
# actual: 17 10 170
# expected:  17 10
# actual: 17 10 170
# expected:  17 10
# actual: 17 10 170
# expected:  17 9
# actual: 17 9 153
# expected:  17 9
# actual: 17 9 153
# expected:  17 9
# actual: 17 9 153
# expected:  17 9
# actual: 17 9 153
# expected:  17 9
# actual: 17 9 153
# expected:  17 9
# actual: 17 9 153
# expected:  17 9
# actual: 17 9 153
# expected:  17 9
# actual: 17 9 153
# expected:  17 7
# actual: 17 7 119
# expected:  17 7
# actual: 17 7 119
# expected:  17 7
# actual: 17 7 119
# expected:  17 7
# actual: 17 7 119
# expected:  17 6
# actual: 17 6 102
# expected:  17 6
# actual: 17 6 102
# expected:  17 5
# actual: 17 5 85
# expected:  17 5
# actual: 17 5 85
# expected:  17 5
# actual: 17 5 85
# expected:  17 5
# actual: 17 5 85
# expected:  17 5
# actual: 17 5 85
# expected:  17 5
# actual: 17 5 85
# expected:  17 3
# actual: 17 3 51
# expected:  17 3
# actual: 17 3 51
# expected:  17 4
# actual: 17 4 68
# expected:  17 4
# actual: 17 4 68
# expected:  17 2
# actual: 17 2 34
# expected:  17 2
# actual: 17 2 34
# expected:  17 3
# actual: 17 3 51
# expected:  17 3
# actual: 17 3 51
# expected:  17 10
# actual: 17 10 170
# expected:  17 10
# actual: 17 10 170
# expected:  16 16
# actual: 16 16 256
# expected:  16 16
# actual: 16 16 256
# expected:  16 13
# actual: 16 13 208
# expected:  16 13
# actual: 16 13 208
# expected:  16 13
# actual: 16 13 208
# expected:  16 13
# actual: 16 13 208
# expected:  16 12
# actual: 16 12 192
# expected:  16 12
# actual: 16 12 192
# expected:  16 11
# actual: 16 11 176
# expected:  16 11
# actual: 16 11 176
# expected:  16 10
# actual: 16 10 160
# expected:  16 10
# actual: 16 10 160
# expected:  16 10
# actual: 16 10 160
# expected:  16 10
# actual: 16 10 160
# expected:  16 9
# actual: 16 9 144
# expected:  16 9
# actual: 16 9 144
# expected:  16 9
# actual: 16 9 144
# expected:  16 9
# actual: 16 9 144
# expected:  16 9
# actual: 16 9 144
# expected:  16 9
# actual: 16 9 144
# expected:  16 9
# actual: 16 9 144
# expected:  16 9
# actual: 16 9 144
# expected:  16 7
# actual: 16 7 112
# expected:  16 7
# actual: 16 7 112
# expected:  16 7
# actual: 16 7 112
# expected:  16 7
# actual: 16 7 112
# expected:  16 6
# actual: 16 6 96
# expected:  16 6
# actual: 16 6 96
# expected:  16 5
# actual: 16 5 80
# expected:  16 5
# actual: 16 5 80
# expected:  16 5
# actual: 16 5 80
# expected:  16 5
# actual: 16 5 80
# expected:  16 5
# actual: 16 5 80
# expected:  16 5
# actual: 16 5 80
# expected:  16 3
# actual: 16 3 48
# expected:  16 3
# actual: 16 3 48
# expected:  16 4
# actual: 16 4 64
# expected:  16 4
# actual: 16 4 64
# expected:  16 2
# actual: 16 2 32
# expected:  16 2
# actual: 16 2 32
# expected:  16 3
# actual: 16 3 48
# expected:  16 3
# actual: 16 3 48
# expected:  16 10
# actual: 16 10 160
# expected:  16 10
# actual: 16 10 160
# expected:  13 13
# actual: 13 13 169
# expected:  13 13
# actual: 13 13 169
# expected:  13 13
# actual: 13 13 169
# expected:  13 13
# actual: 13 13 169
# expected:  13 12
# actual: 13 12 156
# expected:  13 12
# actual: 13 12 156
# expected:  13 11
# actual: 13 11 143
# expected:  13 11
# actual: 13 11 143
# expected:  13 10
# actual: 13 10 130
# expected:  13 10
# actual: 13 10 130
# expected:  13 10
# actual: 13 10 130
# expected:  13 10
# actual: 13 10 130
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 7
# actual: 13 7 91
# expected:  13 7
# actual: 13 7 91
# expected:  13 7
# actual: 13 7 91
# expected:  13 7
# actual: 13 7 91
# expected:  13 6
# actual: 13 6 78
# expected:  13 6
# actual: 13 6 78
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 3
# actual: 13 3 39
# expected:  13 3
# actual: 13 3 39
# expected:  13 4
# actual: 13 4 52
# expected:  13 4
# actual: 13 4 52
# expected:  13 2
# actual: 13 2 26
# expected:  13 2
# actual: 13 2 26
# expected:  13 3
# actual: 13 3 39
# expected:  13 3
# actual: 13 3 39
# expected:  13 10
# actual: 13 10 130
# expected:  13 10
# actual: 13 10 130
# expected:  13 13
# actual: 13 13 169
# expected:  13 13
# actual: 13 13 169
# expected:  13 12
# actual: 13 12 156
# expected:  13 12
# actual: 13 12 156
# expected:  13 11
# actual: 13 11 143
# expected:  13 11
# actual: 13 11 143
# expected:  13 10
# actual: 13 10 130
# expected:  13 10
# actual: 13 10 130
# expected:  13 10
# actual: 13 10 130
# expected:  13 10
# actual: 13 10 130
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 9
# actual: 13 9 117
# expected:  13 7
# actual: 13 7 91
# expected:  13 7
# actual: 13 7 91
# expected:  13 7
# actual: 13 7 91
# expected:  13 7
# actual: 13 7 91
# expected:  13 6
# actual: 13 6 78
# expected:  13 6
# actual: 13 6 78
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 5
# actual: 13 5 65
# expected:  13 3
# actual: 13 3 39
# expected:  13 3
# actual: 13 3 39
# expected:  13 4
# actual: 13 4 52
# expected:  13 4
# actual: 13 4 52
# expected:  13 2
# actual: 13 2 26
# expected:  13 2
# actual: 13 2 26
# expected:  13 3
# actual: 13 3 39
# expected:  13 3
# actual: 13 3 39
# expected:  13 10
# actual: 13 10 130
# expected:  13 10
# actual: 13 10 130
# expected:  12 12
# actual: 12 12 144
# expected:  12 12
# actual: 12 12 144
# expected:  12 11
# actual: 12 11 132
# expected:  12 11
# actual: 12 11 132
# expected:  12 10
# actual: 12 10 120
# expected:  12 10
# actual: 12 10 120
# expected:  12 10
# actual: 12 10 120
# expected:  12 10
# actual: 12 10 120
# expected:  12 9
# actual: 12 9 108
# expected:  12 9
# actual: 12 9 108
# expected:  12 9
# actual: 12 9 108
# expected:  12 9
# actual: 12 9 108
# expected:  12 9
# actual: 12 9 108
# expected:  12 9
# actual: 12 9 108
# expected:  12 9
# actual: 12 9 108
# expected:  12 9
# actual: 12 9 108
# expected:  12 7
# actual: 12 7 84
# expected:  12 7
# actual: 12 7 84
# expected:  12 7
# actual: 12 7 84
# expected:  12 7
# actual: 12 7 84
# expected:  12 6
# actual: 12 6 72
# expected:  12 6
# actual: 12 6 72
# expected:  12 5
# actual: 12 5 60
# expected:  12 5
# actual: 12 5 60
# expected:  12 5
# actual: 12 5 60
# expected:  12 5
# actual: 12 5 60
# expected:  12 5
# actual: 12 5 60
# expected:  12 5
# actual: 12 5 60
# expected:  12 3
# actual: 12 3 36
# expected:  12 3
# actual: 12 3 36
# expected:  12 4
# actual: 12 4 48
# expected:  12 4
# actual: 12 4 48
# expected:  12 2
# actual: 12 2 24
# expected:  12 2
# actual: 12 2 24
# expected:  12 3
# actual: 12 3 36
# expected:  12 3
# actual: 12 3 36
# expected:  12 10
# actual: 12 10 120
# expected:  12 10
# actual: 12 10 120
# expected:  11 11
# actual: 11 11 121
# expected:  11 11
# actual: 11 11 121
# expected:  11 10
# actual: 11 10 110
# expected:  11 10
# actual: 11 10 110
# expected:  11 10
# actual: 11 10 110
# expected:  11 10
# actual: 11 10 110
# expected:  11 9
# actual: 11 9 99
# expected:  11 9
# actual: 11 9 99
# expected:  11 9
# actual: 11 9 99
# expected:  11 9
# actual: 11 9 99
# expected:  11 9
# actual: 11 9 99
# expected:  11 9
# actual: 11 9 99
# expected:  11 9
# actual: 11 9 99
# expected:  11 9
# actual: 11 9 99
# expected:  11 7
# actual: 11 7 77
# expected:  11 7
# actual: 11 7 77
# expected:  11 7
# actual: 11 7 77
# expected:  11 7
# actual: 11 7 77
# expected:  11 6
# actual: 11 6 66
# expected:  11 6
# actual: 11 6 66
# expected:  11 5
# actual: 11 5 55
# expected:  11 5
# actual: 11 5 55
# expected:  11 5
# actual: 11 5 55
# expected:  11 5
# actual: 11 5 55
# expected:  11 5
# actual: 11 5 55
# expected:  11 5
# actual: 11 5 55
# expected:  11 3
# actual: 11 3 33
# expected:  11 3
# actual: 11 3 33
# expected:  11 4
# actual: 11 4 44
# expected:  11 4
# actual: 11 4 44
# expected:  11 2
# actual: 11 2 22
# expected:  11 2
# actual: 11 2 22
# expected:  11 3
# actual: 11 3 33
# expected:  11 3
# actual: 11 3 33
# expected:  11 10
# actual: 11 10 110
# expected:  11 10
# actual: 11 10 110
# expected:  10 10
# actual: 10 10 100
# expected:  10 10
# actual: 10 10 100
# expected:  10 10
# actual: 10 10 100
# expected:  10 10
# actual: 10 10 100
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 7
# actual: 10 7 70
# expected:  10 7
# actual: 10 7 70
# expected:  10 7
# actual: 10 7 70
# expected:  10 7
# actual: 10 7 70
# expected:  10 6
# actual: 10 6 60
# expected:  10 6
# actual: 10 6 60
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 3
# actual: 10 3 30
# expected:  10 3
# actual: 10 3 30
# expected:  10 4
# actual: 10 4 40
# expected:  10 4
# actual: 10 4 40
# expected:  10 2
# actual: 10 2 20
# expected:  10 2
# actual: 10 2 20
# expected:  10 3
# actual: 10 3 30
# expected:  10 3
# actual: 10 3 30
# expected:  10 10
# actual: 10 10 100
# expected:  10 10
# actual: 10 10 100
# expected:  10 10
# actual: 10 10 100
# expected:  10 10
# actual: 10 10 100
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 9
# actual: 10 9 90
# expected:  10 7
# actual: 10 7 70
# expected:  10 7
# actual: 10 7 70
# expected:  10 7
# actual: 10 7 70
# expected:  10 7
# actual: 10 7 70
# expected:  10 6
# actual: 10 6 60
# expected:  10 6
# actual: 10 6 60
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 5
# actual: 10 5 50
# expected:  10 3
# actual: 10 3 30
# expected:  10 3
# actual: 10 3 30
# expected:  10 4
# actual: 10 4 40
# expected:  10 4
# actual: 10 4 40
# expected:  10 2
# actual: 10 2 20
# expected:  10 2
# actual: 10 2 20
# expected:  10 3
# actual: 10 3 30
# expected:  10 3
# actual: 10 3 30
# expected:  10 10
# actual: 10 10 100
# expected:  10 10
# actual: 10 10 100
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 6
# actual: 9 6 54
# expected:  9 6
# actual: 9 6 54
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 3
# actual: 9 3 27
# expected:  9 3
# actual: 9 3 27
# expected:  9 4
# actual: 9 4 36
# expected:  9 4
# actual: 9 4 36
# expected:  9 2
# actual: 9 2 18
# expected:  9 2
# actual: 9 2 18
# expected:  9 3
# actual: 9 3 27
# expected:  9 3
# actual: 9 3 27
# expected:  9 10
# actual: 9 10 90
# expected:  9 10
# actual: 9 10 90
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 6
# actual: 9 6 54
# expected:  9 6
# actual: 9 6 54
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 3
# actual: 9 3 27
# expected:  9 3
# actual: 9 3 27
# expected:  9 4
# actual: 9 4 36
# expected:  9 4
# actual: 9 4 36
# expected:  9 2
# actual: 9 2 18
# expected:  9 2
# actual: 9 2 18
# expected:  9 3
# actual: 9 3 27
# expected:  9 3
# actual: 9 3 27
# expected:  9 10
# actual: 9 10 90
# expected:  9 10
# actual: 9 10 90
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 6
# actual: 9 6 54
# expected:  9 6
# actual: 9 6 54
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 3
# actual: 9 3 27
# expected:  9 3
# actual: 9 3 27
# expected:  9 4
# actual: 9 4 36
# expected:  9 4
# actual: 9 4 36
# expected:  9 2
# actual: 9 2 18
# expected:  9 2
# actual: 9 2 18
# expected:  9 3
# actual: 9 3 27
# expected:  9 3
# actual: 9 3 27
# expected:  9 10
# actual: 9 10 90
# expected:  9 10
# actual: 9 10 90
# expected:  9 9
# actual: 9 9 81
# expected:  9 9
# actual: 9 9 81
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 7
# actual: 9 7 63
# expected:  9 6
# actual: 9 6 54
# expected:  9 6
# actual: 9 6 54
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 5
# actual: 9 5 45
# expected:  9 3
# actual: 9 3 27
# expected:  9 3
# actual: 9 3 27
# expected:  9 4
# actual: 9 4 36
# expected:  9 4
# actual: 9 4 36
# expected:  9 2
# actual: 9 2 18
# expected:  9 2
# actual: 9 2 18
# expected:  9 3
# actual: 9 3 27
# expected:  9 3
# actual: 9 3 27
# expected:  9 10
# actual: 9 10 90
# expected:  9 10
# actual: 9 10 90
# expected:  7 7
# actual: 7 7 49
# expected:  7 7
# actual: 7 7 49
# expected:  7 7
# actual: 7 7 49
# expected:  7 7
# actual: 7 7 49
# expected:  7 6
# actual: 7 6 42
# expected:  7 6
# actual: 7 6 42
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 3
# actual: 7 3 21
# expected:  7 3
# actual: 7 3 21
# expected:  7 4
# actual: 7 4 28
# expected:  7 4
# actual: 7 4 28
# expected:  7 2
# actual: 7 2 14
# expected:  7 2
# actual: 7 2 14
# expected:  7 3
# actual: 7 3 21
# expected:  7 3
# actual: 7 3 21
# expected:  7 10
# actual: 7 10 70
# expected:  7 10
# actual: 7 10 70
# expected:  7 7
# actual: 7 7 49
# expected:  7 7
# actual: 7 7 49
# expected:  7 6
# actual: 7 6 42
# expected:  7 6
# actual: 7 6 42
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 5
# actual: 7 5 35
# expected:  7 3
# actual: 7 3 21
# expected:  7 3
# actual: 7 3 21
# expected:  7 4
# actual: 7 4 28
# expected:  7 4
# actual: 7 4 28
# expected:  7 2
# actual: 7 2 14
# expected:  7 2
# actual: 7 2 14
# expected:  7 3
# actual: 7 3 21
# expected:  7 3
# actual: 7 3 21
# expected:  7 10
# actual: 7 10 70
# expected:  7 10
# actual: 7 10 70
# expected:  6 6
# actual: 6 6 36
# expected:  6 6
# actual: 6 6 36
# expected:  6 5
# actual: 6 5 30
# expected:  6 5
# actual: 6 5 30
# expected:  6 5
# actual: 6 5 30
# expected:  6 5
# actual: 6 5 30
# expected:  6 5
# actual: 6 5 30
# expected:  6 5
# actual: 6 5 30
# expected:  6 3
# actual: 6 3 18
# expected:  6 3
# actual: 6 3 18
# expected:  6 4
# actual: 6 4 24
# expected:  6 4
# actual: 6 4 24
# expected:  6 2
# actual: 6 2 12
# expected:  6 2
# actual: 6 2 12
# expected:  6 3
# actual: 6 3 18
# expected:  6 3
# actual: 6 3 18
# expected:  6 10
# actual: 6 10 60
# expected:  6 10
# actual: 6 10 60
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 3
# actual: 5 3 15
# expected:  5 3
# actual: 5 3 15
# expected:  5 4
# actual: 5 4 20
# expected:  5 4
# actual: 5 4 20
# expected:  5 2
# actual: 5 2 10
# expected:  5 2
# actual: 5 2 10
# expected:  5 3
# actual: 5 3 15
# expected:  5 3
# actual: 5 3 15
# expected:  5 10
# actual: 5 10 50
# expected:  5 10
# actual: 5 10 50
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 3
# actual: 5 3 15
# expected:  5 3
# actual: 5 3 15
# expected:  5 4
# actual: 5 4 20
# expected:  5 4
# actual: 5 4 20
# expected:  5 2
# actual: 5 2 10
# expected:  5 2
# actual: 5 2 10
# expected:  5 3
# actual: 5 3 15
# expected:  5 3
# actual: 5 3 15
# expected:  5 10
# actual: 5 10 50
# expected:  5 10
# actual: 5 10 50
# expected:  5 5
# actual: 5 5 25
# expected:  5 5
# actual: 5 5 25
# expected:  5 3
# actual: 5 3 15
# expected:  5 3
# actual: 5 3 15
# expected:  5 4
# actual: 5 4 20
# expected:  5 4
# actual: 5 4 20
# expected:  5 2
# actual: 5 2 10
# expected:  5 2
# actual: 5 2 10
# expected:  5 3
# actual: 5 3 15
# expected:  5 3
# actual: 5 3 15
# expected:  5 10
# actual: 5 10 50
# expected:  5 10
# actual: 5 10 50
# expected:  3 3
# actual: 3 3 9
# expected:  3 3
# actual: 3 3 9
# expected:  3 4
# actual: 3 4 12
# expected:  3 4
# actual: 3 4 12
# expected:  3 2
# actual: 3 2 6
# expected:  3 2
# actual: 3 2 6
# expected:  3 3
# actual: 3 3 9
# expected:  3 3
# actual: 3 3 9
# expected:  3 10
# actual: 3 10 30
# expected:  3 10
# actual: 3 10 30
# expected:  4 4
# actual: 4 4 16
# expected:  4 4
# actual: 4 4 16
# expected:  4 2
# actual: 4 2 8
# expected:  4 2
# actual: 4 2 8
# expected:  4 3
# actual: 4 3 12
# expected:  4 3
# actual: 4 3 12
# expected:  4 10
# actual: 4 10 40
# expected:  4 10
# actual: 4 10 40
# expected:  2 2
# actual: 2 2 4
# expected:  2 2
# actual: 2 2 4
# expected:  2 3
# actual: 2 3 6
# expected:  2 3
# actual: 2 3 6
# expected:  2 10
# actual: 2 10 20
# expected:  2 10
# actual: 2 10 20
# expected:  3 3
# actual: 3 3 9
# expected:  3 3
# actual: 3 3 9
# expected:  3 10
# actual: 3 10 30
# expected:  3 10
# actual: 3 10 30
# expected:  10 10
# actual: 10 10 100
# expected:  10 10
# actual: 10 10 100
# finished loading data

# %%
print(low_resolution_samples.shape)
print(high_resolution_samples.shape)
# Out:
# (20022, 40, 40, 1)
# (20022, 40, 40, 1)

# %%
sample_size = low_resolution_samples.shape[-2]
padding = conv2d1_filters_size + conv2d2_filters_size + conv2d3_filters_size - 3
half_padding = padding // 2
output_length = sample_size - padding

print("Sample Size: %d"%(sample_size))
print("Padding: %d"%(padding))
print("Half Padding: %d"%(half_padding))
print("Output Length: %d"%(output_length))
# Out:
# Sample Size: 40
# Padding: 12
# Half Padding: 6
# Output Length: 28

# %%
Y_new = high_resolution_samples[:, half_padding:(sample_size-half_padding), half_padding:(sample_size-half_padding), 0]
Y_new = Y_new.reshape(Y_new.shape[0], -2)
X_new = low_resolution_samples
trainSize = 10000
Y_train = high_resolution_samples[:trainSize, half_padding:(sample_size-half_padding), half_padding:(sample_size-half_padding), 0]
Y_train = Y_train.reshape(Y_train.shape[0], -2)
X_train = low_resolution_samples[:trainSize]

Y_val = high_resolution_samples[trainSize:, half_padding:(sample_size-half_padding), half_padding:(sample_size-half_padding), 0]
Y_val = Y_val.reshape(Y_val.shape[0], -2)
X_val = low_resolution_samples[trainSize:]

# %%
print(X_new.shape)
print(Y_new.shape)
print(X_train.shape)
print(Y_train.shape)
print(X_val.shape)
print(Y_val.shape)
# Out:
# (20022, 40, 40, 1)
# (20022, 784)
# (10000, 40, 40, 1)
# (10000, 784)
# (10022, 40, 40, 1)
# (10022, 784)

# %%
tf.reset_default_graph()

Xtf = tf.placeholder(tf.float32, [None, sample_size, sample_size, 1])
ytf = tf.placeholder(tf.float32, [None, Y_train.shape[1]])

def myModel(Xtf,ytf):
    Wconv1 = tf.get_variable("Wconv1", [conv2d1_filters_size, conv2d1_filters_size, 1, conv2d1_filters_numbers])
    bconv1 = tf.get_variable("bconv1", [conv2d1_filters_numbers])
    Wconv2 = tf.get_variable("Wconv2", [conv2d2_filters_size, conv2d2_filters_size, conv2d1_filters_numbers, conv2d2_filters_numbers])
    bconv2 = tf.get_variable("bconv2", [conv2d2_filters_numbers])
    Wconv3 = tf.get_variable("Wconv3", [conv2d3_filters_size, conv2d3_filters_size, conv2d2_filters_numbers, conv2d3_filters_numbers])
    bconv3 = tf.get_variable("bconv3", [conv2d3_filters_numbers])
    
    a1 = tf.nn.conv2d(Xtf, Wconv1, strides=[1, 1, 1, 1], padding='VALID') + bconv1
    h1 = tf.nn.relu(a1)
    a2 = tf.nn.conv2d(h1, Wconv2, strides=[1, 1, 1, 1], padding='VALID')+ bconv2 
    h2 = tf.nn.relu(a2)
    a3 = tf.nn.conv2d(h2, Wconv3, strides=[1, 1, 1, 1], padding='VALID')+ bconv3 
    h3 = tf.nn.relu(a3)
    y_out = tf.reshape(h3, [-1, output_length*output_length])
    return y_out

y_out = myModel(Xtf,ytf)

total_loss = tf.losses.mean_squared_error(ytf,y_out)
mean_loss = tf.reduce_mean(total_loss)

optimizer = tf.train.AdamOptimizer(5e-4)
train_step = optimizer.minimize(mean_loss)

# %%
pylab.rcParams['figure.figsize'] = (40, 20)
def run_model(session, predict, loss_val, Xd, yd,
              epochs=2, batch_size=64, print_every=100,
              training_steps=None, plot_losses=False):
    partitions = [(0,4000),(4000,8000),(8000,12000),(12000,16000),(16000,20022)]
    indicies = np.arange(Xd.shape[0])
    np.random.shuffle(indicies)
    predictYs = []
    train_losses = []
    val_losses = []
    # setting up variables we want to compute (and optimizing)
    # if we have a training function, add that to things we compute
    
    training = [mean_loss,training_steps]
    validation = [mean_loss,predict]
    # counter 
    iter_cnt = 0
    for e in range(epochs):
        train_loss = 0
        val_loss = 0
        # make sure we iterate over the dataset once
        val_par = partitions.pop(0)
        val_indicies = indicies[val_par[0]:val_par[1]]
        train_indicies = np.array([],dtype=int32).reshape(0)
        for par in partitions:
            train_indicies = np.concatenate((train_indicies,indicies[par[0]:par[1]]))
        partitions.append(val_par)
        train_size = train_indicies.shape[0]
        val_size = val_indicies.shape[0]
        for i in range(int(math.ceil(train_size/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%train_size
            end_idx = min(start_idx+batch_size,train_size)
            idx = train_indicies[start_idx:end_idx]
            
            # create a feed dictionary for this batch
            feed_dict = {Xtf: Xd[idx,:],
                         ytf: yd[idx,:],}
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step

            loss,_ = session.run(training,feed_dict=feed_dict)
            
            # aggregate performance stats
            train_loss +=loss*actual_batch_size
            
            # print every now and then
        for i in range(int(math.ceil(val_size/batch_size))):
            # generate indicies for the batch
            start_idx = (i*batch_size)%val_size
            end_idx = min(start_idx+batch_size,val_size)
            idx = train_indicies[start_idx:end_idx]
            
            # create a feed dictionary for this batch
            feed_dict = {Xtf: Xd[idx,:],
                         ytf: yd[idx,:],}
            # get batch size
            actual_batch_size = yd[idx].shape[0]
            
            # have tensorflow compute loss and correct predictions
            # and (if given) perform a training step

            loss,_ = session.run(validation,feed_dict=feed_dict)
            
            # aggregate performance stats
            val_loss +=loss*actual_batch_size
        feed_dict = {Xtf: Xd,
                     ytf: yd,}
        y_out = session.run(predict,feed_dict = feed_dict)
        train_loss = train_loss/train_size
        val_loss = val_loss/val_size
#         print("Iteration {0}: with minibatch training loss = {1:.3g}"\
#                       .format(iter_cnt,loss))
        predictYs.append(y_out)
        print("Epoch {1}, train loss = {0:.3g},val loss = {2:.3g}"\
              .format(train_loss,e+1,val_loss))
#         if plot_losses:
#             plt.plot(losses)
#             plt.grid(True)
#             plt.title('Epoch {} Loss'.format(e+1))
#             plt.xlabel('minibatch number')
#             plt.ylabel('minibatch loss')
#             plt.show()
    return predictYs

with tf.Session() as sess:
    with tf.device("/cpu:0"):
        sess.run(tf.global_variables_initializer())
        print('Training')

        AllPredicted = run_model(sess,y_out,mean_loss,X_new,Y_new,30,64,100,train_step)
# Out:
# Training
# Epoch 1, train loss = 1.2,val loss = 0.532
# Epoch 2, train loss = 0.501,val loss = 0.471
# Epoch 3, train loss = 0.51,val loss = 0.562
# Epoch 4, train loss = 0.48,val loss = 0.441
# Epoch 5, train loss = 0.51,val loss = 0.472
# Epoch 6, train loss = 0.492,val loss = 0.506
# Epoch 7, train loss = 0.478,val loss = 0.451
# Epoch 8, train loss = 0.49,val loss = 0.545
# Epoch 9, train loss = 0.46,val loss = 0.422
# Epoch 10, train loss = 0.491,val loss = 0.452
# Epoch 11, train loss = 0.473,val loss = 0.486
# Epoch 12, train loss = 0.459,val loss = 0.432
# Epoch 13, train loss = 0.47,val loss = 0.524
# Epoch 14, train loss = 0.439,val loss = 0.404
# Epoch 15, train loss = 0.468,val loss = 0.425
# Epoch 16, train loss = 0.45,val loss = 0.459
# Epoch 17, train loss = 0.433,val loss = 0.407
# Epoch 18, train loss = 0.442,val loss = 0.495
# Epoch 19, train loss = 0.411,val loss = 0.379
# Epoch 20, train loss = 0.438,val loss = 0.391
# Epoch 21, train loss = 0.422,val loss = 0.43
# Epoch 22, train loss = 0.403,val loss = 0.379
# Epoch 23, train loss = 0.413,val loss = 0.466
# Epoch 24, train loss = 0.383,val loss = 0.351
# Epoch 25, train loss = 0.409,val loss = 0.36
# Epoch 26, train loss = 0.397,val loss = 0.406
# Epoch 27, train loss = 0.378,val loss = 0.356
# Epoch 28, train loss = 0.388,val loss = 0.442
# Epoch 29, train loss = 0.361,val loss = 0.329
# Epoch 30, train loss = 0.387,val loss = 0.338

# %%
print("number of contact maps: ", len(cache))
cacheIndex = 1
def reconstructFromIndex(cache, predicted, cacheIndex):
    sum_t = 0
    for i in range(cacheIndex):
        sum_t += cache[i][0]
    N, cacheLow, cacheHigh = cache[cacheIndex]
    a1, a2, a3, a4, a5, a6, a7, a8, a9, a10 = cacheLow
    assert N == a9 * a10
    mout = predicted[sum_t:sum_t+N,:].reshape(a9, a10, 28, 28)
    #print(mout.shape )
    #mout = low_resolution_samples[:289, 0, 6:34, 6:34].reshape(17, 17, 28, 28)
    #print(mout.shape )
    out = np.zeros((a9*28, a10*28))
    for i in range(a9-1):
        for j in range(a10-1):
            out[i*28:(i+1)*28, j*28:(j+1)*28] = mout[i, j]
    return out
#for cacheIndex in range(len(cache)):
def reconstructFromFeatures(low_resolution_samples, high_resolution_samples, predicted):
    height = 0
    width = 0
    size_dict = {}
    nss = np.zeros(24, dtype='int32')
    cacheIndex = 0
    for chr1 in range(1, 24):
        for chr2 in range(chr1, 24):
            lowReconstructedByIndex = low_resolution_samples[:, 6:34, 6:34,0]
            lowReconstructedByIndex = reconstructFromIndex(cache, lowReconstructedByIndex, cacheIndex)
            #print("shape: ", lowReconstructedByIndex.shape)
            predReconstructedByIndex = reconstructFromIndex(cache, predicted, cacheIndex)
            highReconstructedByIndex = reconstructFromIndex(cache, Y_new, cacheIndex)
            #ax = plt.subplot(1, 3, 1)
            #ax.imshow(lowReconstructedByIndex)   
            #ax = plt.subplot(1, 3, 2)
            #ax.imshow(predReconstructedByIndex)
            #ax = plt.subplot(1, 3, 3)
            #ax.imshow(highReconstructedByIndex)
            plt.show()
            cacheIndex += 1
            assert lowReconstructedByIndex.shape[0] == highReconstructedByIndex.shape[0]
            assert lowReconstructedByIndex.shape[1] == highReconstructedByIndex.shape[1]
            assert predReconstructedByIndex.shape[0] == highReconstructedByIndex.shape[0]
            assert predReconstructedByIndex.shape[1] == highReconstructedByIndex.shape[1]
            size_dict[(chr1, chr2)] = \
                (lowReconstructedByIndex, highReconstructedByIndex\
                 , predReconstructedByIndex)
            nss[chr1] = np.max([lowReconstructedByIndex.shape[0], nss[chr1]])

    width = height = int(np.sum(nss))
    print("H and W:", width, height)
    lowReconstructed = np.zeros((height, width) )
    highReconstructed = np.zeros((height, width))
    predReconstructed = np.zeros((height, width))
    cacheIndex=0
    for chr1 in range(1, 24):
        for chr2 in range(chr1, 24):
            lowReconstructedByIndex = low_resolution_samples[:,6:34, 6:34,0]
            lowReconstructedByIndex = reconstructFromIndex(cache, lowReconstructedByIndex, cacheIndex)
            #print("shape: ", lowReconstructedByIndex.shape)
            predReconstructedByIndex = reconstructFromIndex(cache, predicted, cacheIndex)
            highReconstructedByIndex = reconstructFromIndex(cache, Y_new, cacheIndex)
            lowReconstructedByIndex, highReconstructedByIndex, predReconstructedByIndex = size_dict[(chr1, chr2)]
            H = int(nss[:chr1].sum())
            W = int(nss[:chr2].sum())
            h, w = lowReconstructedByIndex.shape
            #print(chr1, chr2, H, W, h, w, lowReconstructedByIndex.shape)
            lowReconstructed[H:H+h, W:W+w] = lowReconstructedByIndex * 1.
            highReconstructed[H:H+h, W:W+w] = highReconstructedByIndex * 1.
            predReconstructed[H:H+h, W:W+w] = predReconstructedByIndex * 1.
            if chr1 != chr2:
                lowReconstructed[W:W+w, H:H+h] = lowReconstructedByIndex.T * 1.
                highReconstructed[W:W+w, H:H+h] = highReconstructedByIndex.T * 1.
                predReconstructed[W:W+w, H:H+h] = predReconstructedByIndex.T * 1.            
            cacheIndex += 1
    return lowReconstructed, highReconstructed, predReconstructed, size_dict, nss
# Out:
# number of contact maps:  276

# %%
predictedIndex = -1
lowReconstructed, highReconstructed, predReconstructed, size_dict, nss = reconstructFromFeatures(low_resolution_samples\
                                                                                           , high_resolution_samples\
                                                                                           , AllPredicted[predictedIndex])
chr1 = 5
chr2 = 6
H, W = (np.sum(nss[:chr1]), np.sum(nss[:chr2]))
h, w = size_dict[(chr1, chr2)][1].shape
a = size_dict[(chr1, chr2)][1]
b = highReconstructed[H:H+h, W:W+w]
print("Relative Error: ", rel_error(a, b))
# Out:
# H and W: 5460 5460
# Relative Error:  0.0

# %%
showImages([lowReconstructed[500:800,300:800], highReconstructed[500:800,300:800], predReconstructed[500:800,300:800]])
# Out:
# Number of rows and columns: 1, 3

# %%
partitions = [(0,4000),(4000,8000),(8000,12000),(12000,16000),(16000,20022)]
indicies = np.arange(X_new.shape[0])
predictYs = []

    


val_par = partitions.pop(0)
val_indicies = indicies[val_par[0]:val_par[1]]
train_indicies = np.array([],dtype=int32).reshape(0)
for par in partitions:
    train_indicies = np.concatenate((train_indicies,indicies[par[0]:par[1]]))
partitions.append(val_par)
train_size = train_indicies.shape[0]
val_size = val_indicies.shape[0]
print(train_indicies)
print(val_indicies)
# Out:
# [ 4000  4001  4002 ... 20019 20020 20021]
# [   0    1    2 ... 3997 3998 3999]
